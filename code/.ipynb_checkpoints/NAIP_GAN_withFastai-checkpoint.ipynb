# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import zipfile

naip_zip_fn='/content/gdrive/MyDrive/dataset/naip_imgs4SytleGAN/patches.zip'
naip_unzip_fn=r'/content/naip'

zip_ref=zipfile.ZipFile(naip_zip_fn, 'r')
zip_ref.extractall(naip_unzip_fn)
zip_ref.close()

# %%
from fastai.data.all import *
from fastai.callback.all import *
from fastai.vision.all import *
from fastai.vision.gan import *

from pathlib import Path
import os

# %%
size=64
bs=128

ckpts_path=Path('/content/gdrive/MyDrive/Colab_Notebooks/model_checkpoint/ckpts4NaipGAN')

# %%
dblock=DataBlock(
    blocks=(TransformBlock, ImageBlock),
    get_x=generate_noise,
    get_items=get_image_files,
    splitter=IndexSplitter([]),
    item_tfms=Resize(size, method=ResizeMethod.Crop), 
    batch_tfms=Normalize.from_stats(torch.tensor([0.5,0.5,0.5]), torch.tensor([0.5,0.5,0.5])))

# %%
naip_unzip_fn=r'/content/naip'
imgs_path=Path(os.path.join(naip_unzip_fn,'patches_64'))
dls=dblock.dataloaders(imgs_path, path=imgs_path, bs=bs)

# %%
dls.show_batch(max_n=2)

# %%
generator=basic_generator(64, n_channels=3, n_extra_layers=1)
critic=basic_critic(64, n_channels=3, n_extra_layers=1, act_cls=partial(nn.LeakyReLU, negative_slope=0.2))

# %%
cbs=[SaveModelCallback(monitor='crit_loss',min_delta=0.01,  with_opt=True,fname='naip_wgan_b_ckpt',)] # EarlyStoppingCallback(monitor='gen_loss', min_delta=0.01, patience=10),
learn=GANLearner.wgan(dls, generator, critic, opt_func=RMSProp,
                      path=ckpts_path,
                      cbs=cbs,
                      lr=2e-4,
                      clip=0.01,
                      switcher=FixedGANSwitcher(n_crit=5, n_gen=1),
                      switch_eval=False
                      )

# %%
learn.recorder.train_metrics=True
learn.recorder.valid_metrics=False

# %%
learn.fit_one_cycle(5,wd=0.) # 2e-4
# Out:
# /usr/local/lib/python3.9/dist-packages/fastai/callback/core.py:69: UserWarning: You are shadowing an attribute (generator) that exists in the learner. Use `self.learn.generator` to avoid this
#   warn(f"You are shadowing an attribute ({name}) that exists in the learner. Use `self.learn.{name}` to avoid this")
# /usr/local/lib/python3.9/dist-packages/fastai/callback/core.py:69: UserWarning: You are shadowing an attribute (critic) that exists in the learner. Use `self.learn.critic` to avoid this
#   warn(f"You are shadowing an attribute ({name}) that exists in the learner. Use `self.learn.{name}` to avoid this")
# /usr/local/lib/python3.9/dist-packages/fastai/callback/core.py:69: UserWarning: You are shadowing an attribute (gen_mode) that exists in the learner. Use `self.learn.gen_mode` to avoid this
#   warn(f"You are shadowing an attribute ({name}) that exists in the learner. Use `self.learn.{name}` to avoid this")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>gen_loss</th>
#       <th>crit_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>-0.373378</td>
#       <td>0.030393</td>
#       <td>-0.791030</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>-0.132120</td>
#       <td>-0.786349</td>
#       <td>0.001365</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>-0.120475</td>
#       <td>-0.791523</td>
#       <td>0.006114</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>-0.119367</td>
#       <td>-0.792942</td>
#       <td>0.007538</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>-0.118957</td>
#       <td>-0.793422</td>
#       <td>0.007919</td>
#       <td>00:17</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.9/dist-packages/fastprogress/fastprogress.py:73: UserWarning: Your generator is empty.
#   warn("Your generator is empty.")
# Better model found at epoch 0 with crit_loss value: -0.7910301089286804.

# %% [markdown]
# -1.3153190612792969.
#
# 0.0058530885726213455.

# %%
learn.save(ckpts_path/'naip_wgan_b_learn',with_opt=True)
# Out:
# Path('/content/gdrive/MyDrive/Colab_Notebooks/model_checkpoint/ckpts4NaipGAN/naip_wgan_b_learn.pth')

# %%
learn.show_results(max_n=3, ds_idx=0)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
learn.fit_one_cycle(10)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>gen_loss</th>
#       <th>crit_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>-0.140045</td>
#       <td>-0.781645</td>
#       <td>-0.006004</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>-0.121883</td>
#       <td>-0.788804</td>
#       <td>0.003454</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>-0.119674</td>
#       <td>-0.790415</td>
#       <td>0.004894</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>-0.157016</td>
#       <td>-0.776755</td>
#       <td>-0.011855</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>-0.121234</td>
#       <td>-0.787153</td>
#       <td>0.004684</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>-0.118529</td>
#       <td>-0.793918</td>
#       <td>0.008621</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>-0.117908</td>
#       <td>-0.794716</td>
#       <td>0.009181</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>-0.117625</td>
#       <td>-0.795174</td>
#       <td>0.009725</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>-0.117561</td>
#       <td>-0.795443</td>
#       <td>0.009856</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>-0.117458</td>
#       <td>-0.795554</td>
#       <td>0.010068</td>
#       <td>00:17</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with crit_loss value: -0.006003827787935734.

# %%
learn.show_results(max_n=3, ds_idx=0)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
learn.fit_one_cycle(10)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>gen_loss</th>
#       <th>crit_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>-0.136544</td>
#       <td>-0.788431</td>
#       <td>0.000930</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>-0.122781</td>
#       <td>-0.787607</td>
#       <td>0.002208</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>-0.119893</td>
#       <td>-0.793054</td>
#       <td>0.007485</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>-0.118387</td>
#       <td>-0.794003</td>
#       <td>0.008546</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>-0.119234</td>
#       <td>-0.787945</td>
#       <td>0.002481</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>-0.117843</td>
#       <td>-0.795167</td>
#       <td>0.009688</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>-0.117277</td>
#       <td>-0.795663</td>
#       <td>0.010191</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>-0.117022</td>
#       <td>-0.795965</td>
#       <td>0.010589</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>-0.117000</td>
#       <td>-0.796186</td>
#       <td>0.010779</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>-0.117029</td>
#       <td>-0.796266</td>
#       <td>0.010771</td>
#       <td>00:17</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with crit_loss value: 0.0009298481163568795.

# %%
learn.show_results(max_n=3, ds_idx=0)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
learn.fit_one_cycle(50)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>gen_loss</th>
#       <th>crit_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>-1.132607</td>
#       <td>0.737928</td>
#       <td>-1.531701</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>-1.170055</td>
#       <td>0.746848</td>
#       <td>-1.532495</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>-1.172694</td>
#       <td>0.747661</td>
#       <td>-1.534070</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>-1.174250</td>
#       <td>0.748571</td>
#       <td>-1.535855</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>-1.175223</td>
#       <td>0.749099</td>
#       <td>-1.536975</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>-1.175594</td>
#       <td>0.749533</td>
#       <td>-1.537871</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>-1.175379</td>
#       <td>0.749530</td>
#       <td>-1.537904</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>-1.174331</td>
#       <td>0.748913</td>
#       <td>-1.536782</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>-1.171200</td>
#       <td>0.746039</td>
#       <td>-1.531276</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>-1.168553</td>
#       <td>0.745535</td>
#       <td>-1.529783</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>-1.165325</td>
#       <td>0.744846</td>
#       <td>-1.526804</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>-1.166720</td>
#       <td>0.744735</td>
#       <td>-1.526879</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>-1.166701</td>
#       <td>0.744775</td>
#       <td>-1.526322</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>-1.165829</td>
#       <td>0.743741</td>
#       <td>-1.524313</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>-1.165642</td>
#       <td>0.744034</td>
#       <td>-1.525303</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>-1.164145</td>
#       <td>0.742992</td>
#       <td>-1.522835</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>-1.155874</td>
#       <td>0.739627</td>
#       <td>-1.513888</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>-1.154417</td>
#       <td>0.738152</td>
#       <td>-1.510729</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>-1.156585</td>
#       <td>0.739075</td>
#       <td>-1.512515</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>-1.146155</td>
#       <td>0.737767</td>
#       <td>-1.506835</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>-1.143075</td>
#       <td>0.731531</td>
#       <td>-1.495168</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>-1.148275</td>
#       <td>0.733172</td>
#       <td>-1.501607</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>-1.151096</td>
#       <td>0.736484</td>
#       <td>-1.505724</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>-1.154151</td>
#       <td>0.737158</td>
#       <td>-1.509957</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>-1.151534</td>
#       <td>0.736512</td>
#       <td>-1.508134</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>-1.146069</td>
#       <td>0.732999</td>
#       <td>-1.499538</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>-1.148168</td>
#       <td>0.734976</td>
#       <td>-1.502014</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>-1.148907</td>
#       <td>0.735135</td>
#       <td>-1.502996</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>-1.149012</td>
#       <td>0.736150</td>
#       <td>-1.503821</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>-1.149840</td>
#       <td>0.735729</td>
#       <td>-1.504746</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>-1.151101</td>
#       <td>0.735254</td>
#       <td>-1.505766</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>-1.152082</td>
#       <td>0.736482</td>
#       <td>-1.506712</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>-1.151702</td>
#       <td>0.736701</td>
#       <td>-1.507772</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>-1.154971</td>
#       <td>0.738060</td>
#       <td>-1.511284</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>-1.156580</td>
#       <td>0.738758</td>
#       <td>-1.512354</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>-1.156867</td>
#       <td>0.739137</td>
#       <td>-1.513378</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>-1.157974</td>
#       <td>0.739809</td>
#       <td>-1.514724</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>-1.158106</td>
#       <td>0.740110</td>
#       <td>-1.515412</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>-1.159171</td>
#       <td>0.740415</td>
#       <td>-1.516844</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>-1.159696</td>
#       <td>0.740875</td>
#       <td>-1.516918</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>-1.160289</td>
#       <td>0.741002</td>
#       <td>-1.517553</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>-1.159786</td>
#       <td>0.740993</td>
#       <td>-1.517227</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>-1.160730</td>
#       <td>0.741404</td>
#       <td>-1.518517</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>-1.161463</td>
#       <td>0.741333</td>
#       <td>-1.518822</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>-1.160867</td>
#       <td>0.741497</td>
#       <td>-1.518093</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>-1.160985</td>
#       <td>0.741841</td>
#       <td>-1.519129</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>-1.160906</td>
#       <td>0.741477</td>
#       <td>-1.519016</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>-1.160479</td>
#       <td>0.741535</td>
#       <td>-1.518446</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>-1.161584</td>
#       <td>0.741667</td>
#       <td>-1.519364</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>-1.161348</td>
#       <td>0.741625</td>
#       <td>-1.519251</td>
#       <td>00:17</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with crit_loss value: -1.5317012071609497.

# %%
learn.show_results(max_n=3, ds_idx=0)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
learn.load(ckpts_path/'naip_wgan_b_learn',with_opt=True)

# %%
learn.fit_one_cycle(2,wd=0.) #2e-4
# Out:
# /usr/local/lib/python3.9/dist-packages/fastai/callback/core.py:69: UserWarning: You are shadowing an attribute (generator) that exists in the learner. Use `self.learn.generator` to avoid this
#   warn(f"You are shadowing an attribute ({name}) that exists in the learner. Use `self.learn.{name}` to avoid this")
# /usr/local/lib/python3.9/dist-packages/fastai/callback/core.py:69: UserWarning: You are shadowing an attribute (critic) that exists in the learner. Use `self.learn.critic` to avoid this
#   warn(f"You are shadowing an attribute ({name}) that exists in the learner. Use `self.learn.{name}` to avoid this")
# /usr/local/lib/python3.9/dist-packages/fastai/callback/core.py:69: UserWarning: You are shadowing an attribute (gen_mode) that exists in the learner. Use `self.learn.gen_mode` to avoid this
#   warn(f"You are shadowing an attribute ({name}) that exists in the learner. Use `self.learn.{name}` to avoid this")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>gen_loss</th>
#       <th>crit_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>-0.135426</td>
#       <td>0.079233</td>
#       <td>-0.118669</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>-0.317457</td>
#       <td>0.226573</td>
#       <td>-0.405656</td>
#       <td>00:18</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.9/dist-packages/fastprogress/fastprogress.py:73: UserWarning: Your generator is empty.
#   warn("Your generator is empty.")
# Better model found at epoch 0 with gen_loss value: 0.07923313230276108.
