# %% [markdown]
# > Created on Sun Jul  2 21:35:07 2023 @author: Richie Bao-caDesign设计(cadesign.cn)

# %% [markdown]
# # 3.6-B 城市空间“语言”
#
# ## 3.6.1 基于 LULC 嵌入向量空间 Transformers 视觉模型的地表温度预测试验
#
# ### 3.6.1.1 数据准备
#
#
#
# #### 1) ESA WorldCover（LULC） 数据下载
#
# 欧空局（European Space Agency，ESA）基于 Sentinel-1 和 2 发布了 10 m高空分辨率 [2020年](https://worldcover2020.esa.int/)和[2021年](https://worldcover2021.esa.int/)的全球土地覆盖产品（WorldCover），该产品包含10个分类类别，为林地（Tree Cover）、灌木丛（Shrubland）、草地（Grassland）、农田（Cropland）、建成区（Built-up）、裸地/稀疏植被（Bare / sparse vegetation）、冰雪（Snow and Ice）、永久水体（Permanent water bodies）、草本湿地（Herbaceous Wetland）、苔藓和地衣（Moss and lichen）等10类，并增加有红树林（Mangrove）类，计有11类，其总体精度为77%（独立验证），使用投影 EPSG 编号为4326，即 WGS1984（World Geodetic System of 1984） 的地理坐标系统。
#
# 此次试验的研究范围为伦敦区域，为了能够下载指定区域的 WorldCover 数据，需要先下载 WorldCover 的瓦片网格，由指定区域提取对应的瓦片信息后，确定下载文件路径进行下载。 WorldCover数据的详细说明和下载代码示例可以从其[产品使用手册（Product User Manual）](https://github.com/microsoft/PlanetaryComputerExamples/blob/main/datasets/esa-worldcover/esa-worldcover-example.ipynb)中获取。

# %%
# %load_ext autoreload 
# %autoreload 2 
# %reload_ext autoreload
import usda.models as usda_models
import usda.geodata_process as usda_geodataProcess # conda install gdal; pip instal geopandas;
import usda.datasets as usda_datasets
import usda.data_visual as usda_datavisual

import geopandas as gpd
import pandas as pd
import shapely

import requests
from tqdm.auto import tqdm  # provides a progressbar
import os
import numpy as np
import matplotlib as mpl
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

import pystac_client
import planetary_computer
import rich.table
import matplotlib.colors
import rioxarray as rxr
from matplotlib import cm
import matplotlib.pyplot as plt
from rasterio.plot import show
import copy
import rasterio as rio
import stackstac

from IPython.display import Image,display
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# * 从欧空局下载 WorldCover 数据
#
# 下载 WorldCover 瓦片网格，并转换为 GeoDataFrame 数据格式。为了直观查看瓦片网格的全球分布情况，定义一个随机的颜色映射打印显示地图。定义`esa_worldcover_2020_grid_downloading()`函数实现。

# %%
wc_grid,ranodm_cmap=usda_datasets.esa_worldcover_2020_grid_downloading(show=True)

# %% [markdown]
# 查看 WorldCover 瓦片网格，其字段包含一个几何对象和一个 ID 索引。

# %%
wc_grid.tail(3)
# Out:
#                                                geometry  ll_tile
# 2628  POLYGON ((-144.00000 -27.66528, -144.00530 -27...  S30W147
# 2629  POLYGON ((-177.00000 -44.08407, -177.02234 -44...  S45W180
# 2630  POLYGON ((-177.00000 -43.54951, -176.99759 -43...  S45W177

# %% [markdown]
# 定义`esa_worldcover_downloading()`函数实现根据指定区域`(左下角经度，左下角纬度，右上角经度，右上角纬度)`下载 WorldCover 数据。

# %%
london_bounds=(-1,51.15,1,52)
save_root=r'I:\data\ESA_London'

url_lst,fns,tiles=usda_datasets.esa_worldcover_downloading(london_bounds,save_root,y='2020')
print(url_lst)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 2/2 [00:23<00:00, 11.80s/it]
# ['https://esa-worldcover.s3.eu-central-1.amazonaws.com/v100/2020/map/ESA_WorldCover_10m_2020_v100_N51E000_Map.tif', 'https://esa-worldcover.s3.eu-central-1.amazonaws.com/v100/2020/map/ESA_WorldCover_10m_2020_v100_N51W003_Map.tif']

# %% [markdown]
# 查看返回的 WorldCover 瓦片区域。

# %%
fig, ax=plt.subplots(figsize=(5,5))
tiles.plot(column='ll_tile',cmap=ranodm_cmap,ax=ax)
fig.patch.set_visible(False)
ax.axis('off')
plt.show()

# %% [markdown]
# * 从[Planetary Computer Hub（PcHub）](https://github.com/microsoft/PlanetaryComputerExamples/blob/main/datasets/esa-worldcover/esa-worldcover-example.ipynb)下载 WorldCover 数据或查看信息<sup>[Accessing ESA WorldCover classification data with the Planetary Computer STAC API,<https://github.com/microsoft/PlanetaryComputerExamples/blob/main/datasets/esa-worldcover/esa-worldcover-example.ipynb>]</sup>
#
# 根据指定的范围搜索 WorldCover 数据，返回对应瓦片的 ID。

# %%
catalog=pystac_client.Client.open("https://planetarycomputer.microsoft.com/api/stac/v1",modifier=planetary_computer.sign_inplace,)
search=catalog.search(collections=["esa-worldcover"],bbox=london_bounds)
items=list(search.get_items())
items
# Out:
# [<Item id=ESA_WorldCover_10m_2021_v200_N51W003>,
#  <Item id=ESA_WorldCover_10m_2021_v200_N51E000>,
#  <Item id=ESA_WorldCover_10m_2020_v100_N51W003>,
#  <Item id=ESA_WorldCover_10m_2020_v100_N51E000>]

# %% [markdown]
# 查看数据属性相关信息。

# %%
# Metadata
t_metadata = rich.table.Table("Key", "Value")
for k, v in sorted(items[0].properties.items()):
    t_metadata.add_row(k, str(v))
t_metadata
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Key                            ┃ Value                                              ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ created                        │ 2023-04-06T16:31:45.847838Z                        │
# │ datetime                       │ None                                               │
# │ description                    │ ESA WorldCover product at 10m resolution           │
# │ end_datetime                   │ 2021-12-31T23:59:59Z                               │
# │ esa_worldcover:product_tile    │ N51W003                                            │
# │ esa_worldcover:product_version │ 2.0.0                                              │
# │ grid:code                      │ ESAWORLDCOVER-N51W003                              │
# │ instruments                    │ ['c-sar', 'msi']                                   │
# │ mission                        │ sentinel-1, sentinel-2                             │
# │ platform                       │ sentinel-1a, sentinel-1b, sentinel-2a, sentinel-2b │
# │ proj:epsg                      │ 4326                                               │
# │ start_datetime                 │ 2021-01-01T00:00:00Z                               │
# └────────────────────────────────┴────────────────────────────────────────────────────┘

# %% [markdown]
# 从数据集中获取分类信息和类别颜色配置值。

# %%
class_list=items[0].assets["map"].extra_fields["classification:classes"]
classmap={c["value"]: {"description": c["description"], "hex": c["color-hint"]} for c in class_list}
t=rich.table.Table("Value", "Description", "Hex Color")
for k, v in classmap.items():
    t.add_row(str(k), v["description"], v["hex"])
t
# Out:
# ┏━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┓
# ┃ Value ┃ Description              ┃ Hex Color ┃
# ┡━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━┩
# │ 10    │ Tree cover               │ 006400    │
# │ 20    │ Shrubland                │ FFBB22    │
# │ 30    │ Grassland                │ FFFF4C    │
# │ 40    │ Cropland                 │ F096FF    │
# │ 50    │ Built-up                 │ FA0000    │
# │ 60    │ Bare / sparse vegetation │ B4B4B4    │
# │ 70    │ Snow and ice             │ F0F0F0    │
# │ 80    │ Permanent water bodies   │ 0064C8    │
# │ 90    │ Herbaceous wetland       │ 0096A0    │
# │ 95    │ Mangroves                │ 00CF75    │
# │ 100   │ Moss and lichen          │ FAE6A0    │
# └───────┴──────────────────────────┴───────────┘

# %% [markdown]
# 建立用于土地覆盖地图打印的相关信息，包括分类颜色的映射`cmap`、用于图例的分类值`values`、边界`boundaries`、刻度`ticks`和标签`tick_labels`等。定义`worldcover_cmap4plot()`函数完成计算。

# %%
cmap,values,boundaries,ticks,tick_labels=usda_datavisual.worldcover_cmap4plot()
cmap

# %% [markdown]
# 打开从欧空局下载的 WorldCover 数据，示例中仅打开了一个瓦片。

# %%
london_esa=rxr.open_rasterio(fns[1],masked=True).squeeze()
london_esa
# Out:
# <xarray.DataArray (y: 36000, x: 36000)>
# [1296000000 values with dtype=float32]
# Coordinates:
#     band         int32 1
#   * x            (x) float64 -3.0 -3.0 -3.0 ... -0.0002083 -0.000125 -4.167e-05
#   * y            (y) float64 54.0 54.0 54.0 54.0 54.0 ... 51.0 51.0 51.0 51.0
#     spatial_ref  int32 0
# Attributes: (12/18)
#     algorithm_version:   V1.0.0
#     AREA_OR_POINT:       Area
#     copyright:           ESA WorldCover project 2020 / Contains modified Cope...
#     creation_time:       2021-10-12 16:51:26.705020
#     legend:              10  Tree cover\n    20  Shrubland\n    30  Grassland...
#     license:             CC-BY 4.0 - https://creativecommons.org/licenses/by/...
#     ...                  ...
#     reference:           https://esa-worldcover.org
#     time_end:            2020-12-31T23:59:59Z
#     time_start:          2020-01-01T00:00:00Z
#     title:               ESA WorldCover product at 10m resolution for year 2020
#     scale_factor:        1.0
#     add_offset:          0.0

# %% [markdown]
# 由返回的打印相关信息打印 WorldCover 土地覆盖分类地图。

# %%
fig, ax = plt.subplots(figsize=(16, 14))
normalizer = matplotlib.colors.Normalize(vmin=0, vmax=255)

xy_0=14000
delta=3000
london_esa.isel(y=slice(xy_0, xy_0+delta), x=slice(xy_0,xy_0+delta)).plot(ax=ax, cmap=cmap, norm=normalizer)

colorbar=fig.colorbar(
    cm.ScalarMappable(norm=normalizer, cmap=cmap),
    boundaries=boundaries,
    values=values,
    cax=fig.axes[1].axes,
)
colorbar.set_ticks(ticks, labels=tick_labels)

ax.set_axis_off()
ax.set_title("ESA WorldCover at London");

# %% [markdown]
# #### 2) 地表温度（Land Surface Temperature，LST）数据
#
# 关于地表温度（LST）数据信息可以查看*标记距离*一章，这里从 Planetary Computer Hub 处下载。下载前，通过搜索给定下载区域和数据时段获得满足要求的数据 ID 等相关信息。因为 WorldCover 数据使用的为2020年，因此 LST 选择了同一年份，但仅使用了8月份的数据。

# %%
time_range = "2020-08-07/2020-08-08"

catalog=pystac_client.Client.open("https://planetarycomputer.microsoft.com/api/stac/v1",modifier=planetary_computer.sign_inplace,)
search=catalog.search(collections=["modis-11A2-061"],bbox=london_bounds,datetime=time_range)

items=search.get_all_items()
list(items)
# Out:
# [<Item id=MYD11A2.A2020217.h18v03.061.2021013233159>,
#  <Item id=MYD11A2.A2020217.h17v03.061.2021013233157>,
#  <Item id=MOD11A2.A2020217.h18v03.061.2021013224226>,
#  <Item id=MOD11A2.A2020217.h17v03.061.2021013223600>]

# %% [markdown]
# 查看 LST 数据属性信息，如下。

# %%
items[0].properties
# Out:
# {'created': '2021-01-13T23:31:59Z',
#  'updated': '2021-01-13T17:38:42.615000Z',
#  'datetime': None,
#  'platform': 'aqua',
#  'proj:epsg': None,
#  'proj:wkt2': 'PROJCS["unnamed",GEOGCS["Unknown datum based upon the custom spheroid",DATUM["Not specified (based on custom spheroid)",SPHEROID["Custom spheroid",6371007.181,0]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Sinusoidal"],PARAMETER["longitude_of_center",0],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["Meter",1],AXIS["Easting",EAST],AXIS["Northing",NORTH]]',
#  'proj:shape': [1200, 1200],
#  'instruments': ['modis'],
#  'end_datetime': '2020-08-11T23:59:59Z',
#  'modis:tile-id': '51018003',
#  'proj:geometry': {'type': 'Polygon',
#   'coordinates': [[[1111950.519767, 5559752.598833],
#     [1111950.519767, 6671703.118599],
#     [0.0, 6671703.118599],
#     [0.0, 5559752.598833],
#     [1111950.519767, 5559752.598833]]]},
#  'proj:transform': [926.6254331391667,
#   0.0,
#   0.0,
#   0.0,
#   -926.6254331383334,
#   6671703.118599],
#  'start_datetime': '2020-08-04T00:00:00Z',
#  'modis:vertical-tile': 3,
#  'modis:horizontal-tile': 18}

# %% [markdown]
# 查看 LST 数据层信息，如下。其中，`LST_Day_1km`为地表温度数据层。

# %%
table = rich.table.Table("Asset Key", "Description")
for asset_key, asset in items[0].assets.items():
    table.add_row(asset_key, asset.title)

table
# Out:
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Asset Key        ┃ Description                                                     ┃
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ hdf              │ Source data containing all bands                                │
# │ QC_Day           │ Quality control for daytime LST and emissivity                  │
# │ Emis_31          │ Band 31 emissivity                                              │
# │ Emis_32          │ Band 32 emissivity                                              │
# │ QC_Night         │ Quality control for nighttime LST and emissivity                │
# │ metadata         │ Federal Geographic Data Committee (FGDC) Metadata               │
# │ LST_Day_1km      │ 8-day daytime 1km grid Landsurface Temperature                  │
# │ Day_view_angl    │ Average view zenith angle of daytime Land-surface Temperature   │
# │ Day_view_time    │ Average time of daytime Landsurface Temperature observation     │
# │ LST_Night_1km    │ 8-day nighttime 1km grid Landsurface Temperature                │
# │ Clear_sky_days   │ the days in clear-sky conditions and with validate LSTs         │
# │ Night_view_angl  │ View zenith angle of nighttime Land-surface Temperature         │
# │ Night_view_time  │ Average view zenith angle of nighttime Land-surface Temperature │
# │ Clear_sky_nights │ the nights in clear-sky conditions and with validate LSTs       │
# │ tilejson         │ TileJSON with default rendering                                 │
# │ rendered_preview │ Rendered preview                                                │
# └──────────────────┴─────────────────────────────────────────────────────────────────┘

# %% [markdown]
# 打印 LST 数据，确定为所选区域的数据。

# %%
print(items[1].assets.keys())
im_01=Image(url=items[1].assets["rendered_preview"].href,width=500)
im_02=Image(url=items[0].assets["rendered_preview"].href,width=500)

display(im_01, im_02)
# Out:
# dict_keys(['hdf', 'QC_Day', 'Emis_31', 'Emis_32', 'QC_Night', 'metadata', 'LST_Day_1km', 'Day_view_angl', 'Day_view_time', 'LST_Night_1km', 'Clear_sky_days', 'Night_view_angl', 'Night_view_time', 'Clear_sky_nights', 'tilejson', 'rendered_preview'])
# <img src="https://planetarycomputer.microsoft.com/api/data/v1/item/preview.png?collection=modis-11A2-061&item=MYD11A2.A2020217.h17v03.061.2021013233157&assets=LST_Day_1km&tile_format=png&colormap_name=jet&rescale=255%2C310&format=png" width="500"/>
# <img src="https://planetarycomputer.microsoft.com/api/data/v1/item/preview.png?collection=modis-11A2-061&item=MYD11A2.A2020217.h18v03.061.2021013233159&assets=LST_Day_1km&tile_format=png&colormap_name=jet&rescale=255%2C310&format=png" width="500"/>

# %%
items[0].assets['LST_Day_1km']
# Out:
# <Asset href=https://modiseuwest.blob.core.windows.net/modis-061-cogs/MYD11A2/18/03/2020217/MYD11A2.A2020217.h18v03.061.2021013233159_LST_Day_1km.tif?st=2023-07-06T04%3A10%3A39Z&se=2023-07-07T04%3A55%3A39Z&sp=rl&sv=2021-06-08&sr=c&skoid=c85c15d6-d1ae-42d4-af60-e2ca0f81359b&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2023-07-07T00%3A49%3A38Z&ske=2023-07-14T00%3A49%3A38Z&sks=b&skv=2021-06-08&sig=AReev5kZKP4CyN3Jj0oQsCU3lvNp%2B8puqGbTreSdDVA%3D>

# %%
url_lst=[]
for item in items:
    url_lst.append(item.assets['LST_Day_1km'].href)

# %%
url_lst
# Out:
# ['https://modiseuwest.blob.core.windows.net/modis-061-cogs/MYD11A2/18/03/2020217/MYD11A2.A2020217.h18v03.061.2021013233159_LST_Day_1km.tif?st=2023-07-08T12%3A58%3A20Z&se=2023-07-09T13%3A43%3A20Z&sp=rl&sv=2021-06-08&sr=c&skoid=c85c15d6-d1ae-42d4-af60-e2ca0f81359b&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2023-07-09T09%3A15%3A16Z&ske=2023-07-16T09%3A15%3A16Z&sks=b&skv=2021-06-08&sig=7qQLC08/%2Bp57EGKBhLfSOMqsQl4w6DG7Gw5EY3LIugs%3D',
#  'https://modiseuwest.blob.core.windows.net/modis-061-cogs/MYD11A2/17/03/2020217/MYD11A2.A2020217.h17v03.061.2021013233157_LST_Day_1km.tif?st=2023-07-08T12%3A58%3A20Z&se=2023-07-09T13%3A43%3A20Z&sp=rl&sv=2021-06-08&sr=c&skoid=c85c15d6-d1ae-42d4-af60-e2ca0f81359b&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2023-07-09T09%3A15%3A16Z&ske=2023-07-16T09%3A15%3A16Z&sks=b&skv=2021-06-08&sig=7qQLC08/%2Bp57EGKBhLfSOMqsQl4w6DG7Gw5EY3LIugs%3D',
#  'https://modiseuwest.blob.core.windows.net/modis-061-cogs/MOD11A2/18/03/2020217/MOD11A2.A2020217.h18v03.061.2021013224226_LST_Day_1km.tif?st=2023-07-08T12%3A58%3A20Z&se=2023-07-09T13%3A43%3A20Z&sp=rl&sv=2021-06-08&sr=c&skoid=c85c15d6-d1ae-42d4-af60-e2ca0f81359b&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2023-07-09T09%3A15%3A16Z&ske=2023-07-16T09%3A15%3A16Z&sks=b&skv=2021-06-08&sig=7qQLC08/%2Bp57EGKBhLfSOMqsQl4w6DG7Gw5EY3LIugs%3D',
#  'https://modiseuwest.blob.core.windows.net/modis-061-cogs/MOD11A2/17/03/2020217/MOD11A2.A2020217.h17v03.061.2021013223600_LST_Day_1km.tif?st=2023-07-08T12%3A58%3A20Z&se=2023-07-09T13%3A43%3A20Z&sp=rl&sv=2021-06-08&sr=c&skoid=c85c15d6-d1ae-42d4-af60-e2ca0f81359b&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2023-07-09T09%3A15%3A16Z&ske=2023-07-16T09%3A15%3A16Z&sks=b&skv=2021-06-08&sig=7qQLC08/%2Bp57EGKBhLfSOMqsQl4w6DG7Gw5EY3LIugs%3D']

# %%
save_root=r'E:\data\LST\LST_London'

fns=[]
i=0
for url in tqdm(url_lst):    
    #print(url)
    r = requests.get(url, allow_redirects=True)
    #print(r)
    out_fn = os.path.join(save_root,f"LST_{i}.tif")
    fns.append(out_fn)
    with open(out_fn, 'wb') as f:
        f.write(r.content)

    i+=1
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 4/4 [02:15<00:00, 33.92s/it]

# %%
fns=['E:\\data\\LST\\LST_London\\LST_0.tif',
     'E:\\data\\LST\\LST_London\\LST_1.tif',
     'E:\\data\\LST\\LST_London\\LST_2.tif',
     'E:\\data\\LST\\LST_London\\LST_3.tif']

# %%
lst_mosaic_fn=os.path.join(save_root,'lst_london.tif')
usda_geodataProcess.raster_mosaic(r'E:\data\LST\LST_London\LST_london',lst_mosaic_fn)
# Out:
# Affine(926.6254331391667, 0.0, -1111950.519767,
#        0.0, -926.6254331383334, 6671703.118599)

# %%
bounds=london_esa.rio.bounds()
bounds
# Out:
# (-3.0, 51.0, -5.0923620788928536e-17, 54.0)

# %%
lst_4326_fn=os.path.join(save_root,'lst_london_4326.tif')
#usda_geodataProcess.raster_reprojection(lst_mosaic_fn,lst_4326_fn,rio.crs.CRS.from_epsg(4326))

# %%
save_root=r'E:\data\LST\LST_London'
lst_mosaic_fn=os.path.join(save_root,'lst_london.tif')

with rio.open(lst_mosaic_fn) as src:    
    epsg_LST=src.crs
    

LST_pt_leftBottom_pj=usda_geodataProcess.pt_coordi_transform("epsg:4326",epsg_LST,bounds[:2])
LST_pt_rightTop_pj=usda_geodataProcess.pt_coordi_transform(4326,epsg_LST,bounds[2:])

# %%
crs=london_esa.rio.crs
bounds=london_esa.rio.bounds()
print(crs,bounds)
# Out:
# GEOGCS["WGS 84",DATUM["World Geodetic System 1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST]] (-3.0, 51.0, -5.0923620788928536e-17, 54.0)

# %%
LST_temp,LST_transform,LST_ras_meta=usda_geodataProcess.rio_read_subset(lst_mosaic_fn,[LST_pt_leftBottom_pj,LST_pt_rightTop_pj])

# %%
cmap=mpl.cm.twilight_shifted

f, ax=plt.subplots(figsize=(16,14))
show(LST_temp,ax=ax,transform=LST_transform,cmap=cmap) # .reversed()
plt.show()

# %%
LST_London_fn=r'I:\data\london\LST_London_02.tif'

LST_ras_meta_=copy.deepcopy(LST_ras_meta)
LST_ras_meta_.update(   
        compress='lzw',
        )  
with rio.open(LST_London_fn,'w',**LST_ras_meta_) as dst:
    dst.write(LST_temp)

# %%
rasterfn =r'I:\data\london\LST_London_02.tif'
outSHPfn = r'I:\data\london\LST_London_02.shp'  

raster=rxr.open_rasterio(rasterfn)

x, y, vals = raster.x.values, raster.y.values, raster.values

x, y = np.meshgrid(x, y)
x, y, vals= x.flatten(), y.flatten(), vals.flatten()

raster_pd = pd.DataFrame.from_dict({'vals': vals, 'x': x, 'y': y})
raster_gpd = gpd.GeoDataFrame(geometry=gpd.GeoSeries.from_xy(raster_pd['x'], raster_pd['y'], crs=raster.rio.crs))
cell_x,cell_y=raster.rio.resolution()

raster_gpd['geometry']= raster_gpd.buffer(cell_x/2,cap_style=3)
raster_merged=raster_gpd.merge(raster_pd,left_index=True, right_index=True)

raster_merged.to_file(outSHPfn)

# %%
raster_merged
# Out:
#                                                 geometry   vals  \
# 0      POLYGON ((-209417.348 6004532.807, -209417.348...      0
# 1      POLYGON ((-208490.722 6004532.807, -208490.722...      0
# 2      POLYGON ((-207564.097 6004532.807, -207564.097...      0
# 3      POLYGON ((-206637.472 6004532.807, -206637.472...      0
# 4      POLYGON ((-205710.846 6004532.807, -205710.846...      0
# ...                                                  ...    ...
# 81715  POLYGON ((-3706.502 5671874.276, -3706.502 567...  15367
# 81716  POLYGON ((-2779.876 5671874.276, -2779.876 567...  15365
# 81717  POLYGON ((-1853.251 5671874.276, -1853.251 567...  15381
# 81718  POLYGON ((-926.625 5671874.276, -926.625 56709...  15388
# 81719  POLYGON ((-0.000 5671874.276, -0.000 5670947.6...  15358
#
#                    x             y
# 0     -209880.660606  6.004069e+06
# 1     -208954.035173  6.004069e+06
# 2     -208027.409740  6.004069e+06
# 3     -207100.784307  6.004069e+06
# 4     -206174.158873  6.004069e+06
# ...              ...           ...
# 81715   -4169.814449  5.671411e+06
# 81716   -3243.189016  5.671411e+06
# 81717   -2316.563583  5.671411e+06
# 81718   -1389.938150  5.671411e+06
# 81719    -463.312717  5.671411e+06
#
# [81720 rows x 4 columns]

# %% [markdown]
# #### 3) 构建数据集

# %%
import mapclassify
from sklearn.utils import Bunch
import pickle
from tqdm import tqdm
import rioxarray as rxr
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt

from torchvision import transforms
from sklearn.model_selection import train_test_split
import torch
from torch.utils.data import TensorDataset, DataLoader
import torchvision

# %%
outSHPfn = r'I:\data\london\LST_London_02.shp'  

LST_gdf=gpd.read_file(outSHPfn)
LST_gdf.drop(LST_gdf[LST_gdf['vals']==0].index,inplace=True)
LST_gdf.vals.describe()
# Out:
# count    78710.000000
# mean     15236.201893
# std        199.266549
# min      14119.000000
# 25%      15128.000000
# 50%      15264.000000
# 75%      15371.000000
# max      15795.000000
# Name: vals, dtype: float64

# %%
LST_EqualInterval=mapclassify.EqualInterval(LST_gdf['vals'],k=10) # k=5

# %%
LST_EqualInterval
# Out:
# EqualInterval
#
#       Interval         Count
# ----------------------------
# [14119.00, 14286.60] |    27
# (14286.60, 14454.20] |   109
# (14454.20, 14621.80] |   382
# (14621.80, 14789.40] |  1587
# (14789.40, 14957.00] |  5673
# (14957.00, 15124.60] | 11597
# (15124.60, 15292.20] | 25553
# (15292.20, 15459.80] | 25417
# (15459.80, 15627.40] |  7770
# (15627.40, 15795.00] |   595

# %%
LST_gdf['rank']=LST_EqualInterval.yb
LST_gdf
# Out:
#         vals              x             y  \
# 25     14646 -186715.024778  6.004069e+06
# 26     14672 -185788.399344  6.004069e+06
# 27     14708 -184861.773911  6.004069e+06
# 28     14730 -183935.148478  6.004069e+06
# 29     14764 -183008.523045  6.004069e+06
# ...      ...            ...           ...
# 81715  15367   -4169.814449  5.671411e+06
# 81716  15365   -3243.189016  5.671411e+06
# 81717  15381   -2316.563583  5.671411e+06
# 81718  15388   -1389.938150  5.671411e+06
# 81719  15358    -463.312717  5.671411e+06
#
#                                                 geometry  rank
# 25     POLYGON ((-186251.712 6004532.807, -186251.712...     3
# 26     POLYGON ((-185325.087 6004532.807, -185325.087...     3
# 27     POLYGON ((-184398.461 6004532.807, -184398.461...     3
# 28     POLYGON ((-183471.836 6004532.807, -183471.836...     3
# 29     POLYGON ((-182545.210 6004532.807, -182545.210...     3
# ...                                                  ...   ...
# 81715  POLYGON ((-3706.502 5671874.276, -3706.502 567...     7
# 81716  POLYGON ((-2779.876 5671874.276, -2779.876 567...     7
# 81717  POLYGON ((-1853.251 5671874.276, -1853.251 567...     7
# 81718  POLYGON ((-926.625 5671874.276, -926.625 56709...     7
# 81719  POLYGON ((-0.000 5671874.276, -0.000 5670947.6...     7
#
# [78710 rows x 5 columns]

# %%
LC_fn=r'I:\\data\\ESA_London\\ESA_WorldCover_10m_2020_v100_N51W003_Map.tif'
LC= rxr.open_rasterio(LC_fn)

# %%
LST_gdf.to_crs(LC.rio.crs,inplace=True)

# %%
LST_gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - undefined
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
LST_rank_fn=r'I:\data\london\LST_rank_10.shp'
LST_gdf.to_file(LST_rank_fn)

# %%
LST_rank_fn=r'I:\data\london\LST_rank_10.shp'
LST_rank=gpd.read_file(LST_rank_fn)

# %% [markdown]
# 构建数据集；(1, 1, 90, 157) clipped_LC.data[:,5:95,10:167].shape

# %%
#dataset_fn='I:\data\london\LC2LST_dataset_2.pickle'
dataset_fn='I:\data\london\LC2LST_dataset_10.pickle'
with open(dataset_fn,'rb') as f:
    ds=pickle.load(f)

# %%
sample=ds.data[0]
print(f'data shape:{sample.shape};\ndata:\n{sample};\ntarget={ds.target[0]}')
# Out:
# data shape:(1, 90, 150);
# data:
# [[[80 80 80 ... 50 50 50]
#   [80 80 80 ... 50 50 50]
#   [80 80 80 ... 50 50 50]
#   ...
#   [30 30 30 ... 30 30 30]
#   [30 30 30 ... 30 30 30]
#   [30 30 30 ... 30 30 30]]];
# target=3

# %%
plt.imshow(sample[0], cmap=cmap, norm=normalizer);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 plt.imshow(sample[0], cmap=cmap, norm=normalizer);
#
# NameError: name 'cmap' is not defined

# %%
test_transform = transforms.Compose([transforms.ToTensor(),
                                     transforms.Normalize([0.49139968, 0.48215841, 0.44653091], [0.24703223, 0.24348513, 0.26158784])
                                     ])
# For training, we add some augmentation. Networks are too powerful and would overfit.
train_transform = transforms.Compose([    
    #transforms.RandomHorizontalFlip(),
    #transforms.RandomResizedCrop((90,157),scale=(0.8,1.0),ratio=(0.9,1.1)),
    #transforms.ToTensor(),
    #transforms.ToPILImage(),
    transforms.Normalize([0.49139968], [0.24703223])
    ])

# %%
x_train, x_test, y_train, y_test = train_test_split(ds.data, ds.target,test_size=0.2)
x_train, x_test, y_train, y_test=torch.Tensor(x_train), torch.Tensor(x_test), torch.Tensor(y_train).type(torch.LongTensor), torch.Tensor(y_test).type(torch.LongTensor) #@ .type(torch.LongTensor)
train_ds=TensorDataset(x_train,y_train)
train_dl=DataLoader(train_ds,batch_size=128, shuffle=True, drop_last=True, pin_memory=True, num_workers=4)

test_ds=TensorDataset(x_test,y_test)
test_dl=DataLoader(test_ds,batch_size=128, shuffle=False, drop_last=False, num_workers=4)

# %%
x_train[0]
# Out:
# tensor([[[10., 10., 40.,  ..., 10., 10., 10.],
#          [40., 40., 40.,  ..., 10., 10., 10.],
#          [40., 40., 40.,  ..., 10., 10., 10.],
#          ...,
#          [30., 30., 30.,  ..., 40., 40., 40.],
#          [30., 30., 30.,  ..., 40., 40., 40.],
#          [30., 30., 30.,  ..., 40., 40., 40.]]])

# %%
for i in train_dl:
    d=i[0]
    print(d.shape,type(d))
    t=i[1]
    print(t.shape,type(t))
    break
# Out:
# torch.Size([128, 1, 90, 150]) <class 'torch.Tensor'>
# torch.Size([128]) <class 'torch.Tensor'>

# %%
torch.int
# Out:
# torch.int32

# %%
img_patches = usda_models.img_to_patch(x_train, patch_size=15, flatten_channels=False)
print(img_patches.shape)

fig, ax = plt.subplots(10, 1, figsize=(20,5))
fig.suptitle("Images as input sequences of patches")
for i in range(10):
    img_grid = torchvision.utils.make_grid(img_patches[i], nrow=60, normalize=True, pad_value=0.9)
    img_grid = img_grid.permute(1, 2, 0)
    ax[i].imshow(img_grid)
    ax[i].axis('off')
plt.show()
plt.close()
# Out:
# torch.Size([61346, 60, 1, 15, 15])

# %% [markdown]
# #### 4) 训练视觉模型

# %%
# %load_ext autoreload 
# %autoreload 2 
# %reload_ext autoreload
import usda.models as usda_models

import pytorch_lightning as pl
from pytorch_lightning.callbacks import LearningRateMonitor, ModelCheckpoint
from pytorch_lightning.loggers import TensorBoardLogger
import torch
import os
# Out:
# C:\Users\richi\anaconda3\envs\proj\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\richi\anaconda3\envs\proj\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
# C:\Users\richi\anaconda3\envs\proj\lib\site-packages\numpy\.libs\libopenblas64__v0.3.23-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
model_kwargs=dict(embed_dim=256, 
    hidden_dim=512, 
    num_channels=1, 
    num_heads=8, 
    num_layers=6, 
    num_classes=10, 
    patch_size=15, 
    num_patches=60, 
    dropout=0.2)

#vit=usda_models.ViT(model_kwargs,lr=3e-4)
#print(vit.model)

# %%
CHECKPOINT_PATH=r'I:\model_ckpts\ViT_LC_LST_02'#r'I:\model_ckpts\ViT_LC_LST'
device = torch.device("cuda:0") if torch.cuda.is_available() else torch.device("cpu")
logger = TensorBoardLogger(os.path.join(CHECKPOINT_PATH, "tensorboard"), name="lclst")

trainer = pl.Trainer(default_root_dir=os.path.join(CHECKPOINT_PATH, "ViT"),
                     accelerator="gpu" if str(device).startswith("cuda") else "cpu",
                     logger=logger,
                     devices=1,
                     max_epochs=180,
                     callbacks=[ModelCheckpoint(save_weights_only=True, mode="max", monitor="val_acc"),
                                LearningRateMonitor("epoch")])
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs

# %%
trainer.logger._log_graph = True         # If True, we plot the computation graph in tensorboard
trainer.logger._default_hp_metric = None # Optional logging argument that we don't need

# %%
os.path.isfile(pretrained_filename)
# Out:
# False

# %%
# Check whether pretrained model exists. If yes, load it and skip training
pretrained_filename = os.path.join(CHECKPOINT_PATH, "ViT.ckpt")
if os.path.isfile(pretrained_filename):
    print(f"Found pretrained model at {pretrained_filename}, loading...")
    model = usda_models.ViT.load_from_checkpoint(pretrained_filename) # Automatically loads the model with the saved hyperparameters
else:
    pl.seed_everything(42) # To be reproducable
    model = usda_models.ViT(model_kwargs,lr=3e-4)
    trainer.fit(model, train_dl, test_dl)
    model = usda_models.ViT.load_from_checkpoint(trainer.checkpoint_callback.best_model_path) # Load best checkpoint after training
    
test_result = trainer.test(model, test_dl, verbose=False)
result = {"test": test_result[0]["test_acc"]}
print("ViT results", result)
# Out:
# Global seed set to 42
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type              | Params
# --------------------------------------------
# 0 | model | VisionTransformer | 3.2 M
# --------------------------------------------
# 3.2 M     Trainable params
# 0         Non-trainable params
# 3.2 M     Total params
# 12.958    Total estimated model params size (MB)
# Epoch 3:   0%|                                                              | 0/479 [03:20<?, ?it/s, v_num=0]
# Epoch 3: 100%|████████████████████████████████████████████████████| 479/479 [00:37<00:00, 12.71it/s, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                    | 0/120 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                       | 0/120 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|▍                                              | 1/120 [00:00<00:04, 26.67it/s]
# Validation DataLoader 0:   2%|▊                                              | 2/120 [00:00<00:04, 27.97it/s]
# Validation DataLoader 0:   2%|█▏                                             | 3/120 [00:00<00:04, 28.43it/s]
# Validation DataLoader 0:   3%|█▌                                             | 4/120 [00:00<00:04, 27.49it/s]
# Validation DataLoader 0:   4%|█▉                                             | 5/120 [00:00<00:04, 26.81it/s]
# Validation DataLoader 0:   5%|██▎                                            | 6/120 [00:00<00:04, 26.03it/s]
# Validation DataLoader 0:   6%|██▋                                            | 7/120 [00:00<00:04, 25.53it/s]
# Validation DataLoader 0:   7%|███▏                                           | 8/120 [00:00<00:04, 25.96it/s]
# Validation DataLoader 0:   8%|███▌                                           | 9/120 [00:00<00:04, 26.07it/s]
# Validation DataLoader 0:   8%|███▊                                          | 10/120 [00:00<00:04, 26.10it/s]
# Validation DataLoader 0:   9%|████▏                                         | 11/120 [00:00<00:04, 26.39it/s]
# Validation DataLoader 0:  10%|████▌                                         | 12/120 [00:00<00:04, 26.38it/s]
# Validation DataLoader 0:  11%|████▉                                         | 13/120 [00:00<00:03, 26.81it/s]
# Validation DataLoader 0:  12%|█████▎                                        | 14/120 [00:00<00:03, 27.14it/s]
# Validation DataLoader 0:  12%|█████▊                                        | 15/120 [00:00<00:03, 27.33it/s]
# Validation DataLoader 0:  13%|██████▏                                       | 16/120 [00:00<00:03, 26.76it/s]
# Validation DataLoader 0:  14%|██████▌                                       | 17/120 [00:00<00:03, 26.45it/s]
# Validation DataLoader 0:  15%|██████▉                                       | 18/120 [00:00<00:03, 26.37it/s]
# Validation DataLoader 0:  16%|███████▎                                      | 19/120 [00:00<00:03, 26.48it/s]
# Validation DataLoader 0:  17%|███████▋                                      | 20/120 [00:00<00:03, 26.65it/s]
# Validation DataLoader 0:  18%|████████                                      | 21/120 [00:00<00:03, 26.76it/s]
# Validation DataLoader 0:  18%|████████▍                                     | 22/120 [00:00<00:03, 26.74it/s]
# Validation DataLoader 0:  19%|████████▊                                     | 23/120 [00:00<00:03, 26.79it/s]
# Validation DataLoader 0:  20%|█████████▏                                    | 24/120 [00:00<00:03, 26.43it/s]
# Validation DataLoader 0:  21%|█████████▌                                    | 25/120 [00:00<00:03, 26.29it/s]
# Validation DataLoader 0:  22%|█████████▉                                    | 26/120 [00:00<00:03, 26.35it/s]
# Validation DataLoader 0:  22%|██████████▎                                   | 27/120 [00:01<00:03, 26.61it/s]
# Validation DataLoader 0:  23%|██████████▋                                   | 28/120 [00:01<00:03, 26.88it/s]
# Validation DataLoader 0:  24%|███████████                                   | 29/120 [00:01<00:03, 27.16it/s]
# Validation DataLoader 0:  25%|███████████▌                                  | 30/120 [00:01<00:03, 27.31it/s]
# Validation DataLoader 0:  26%|███████████▉                                  | 31/120 [00:01<00:03, 27.57it/s]
# Validation DataLoader 0:  27%|████████████▎                                 | 32/120 [00:01<00:03, 27.84it/s]
# Validation DataLoader 0:  28%|████████████▋                                 | 33/120 [00:01<00:03, 27.88it/s]
# Validation DataLoader 0:  28%|█████████████                                 | 34/120 [00:01<00:03, 27.83it/s]
# Validation DataLoader 0:  29%|█████████████▍                                | 35/120 [00:01<00:03, 27.58it/s]
# Validation DataLoader 0:  30%|█████████████▊                                | 36/120 [00:01<00:03, 26.16it/s]
# Validation DataLoader 0:  31%|██████████████▏                               | 37/120 [00:01<00:03, 25.55it/s]
# Validation DataLoader 0:  32%|██████████████▌                               | 38/120 [00:01<00:03, 25.35it/s]
# Validation DataLoader 0:  32%|██████████████▉                               | 39/120 [00:01<00:03, 25.27it/s]
# Validation DataLoader 0:  11%|████▉                                         | 13/120 [00:00<00:04, 21.56it/s]
# Validation DataLoader 0:  12%|█████▎                                        | 14/120 [00:00<00:04, 21.88it/s]
# Validation DataLoader 0:  12%|█████▊                                        | 15/120 [00:00<00:04, 22.03it/s]
# Validation DataLoader 0:  13%|██████▏                                       | 16/120 [00:00<00:04, 22.29it/s]
# Validation DataLoader 0:  14%|██████▌                                       | 17/120 [00:00<00:04, 22.46it/s]
# Validation DataLoader 0:  15%|██████▉                                       | 18/120 [00:00<00:04, 22.50it/s]
# Validation DataLoader 0:  16%|███████▎                                      | 19/120 [00:00<00:04, 22.68it/s]
# Validation DataLoader 0:  17%|███████▋                                      | 20/120 [00:00<00:04, 22.70it/s]
# Validation DataLoader 0:  18%|████████                                      | 21/120 [00:00<00:04, 22.76it/s]
# Validation DataLoader 0:  18%|████████▍                                     | 22/120 [00:00<00:04, 22.78it/s]
# Validation DataLoader 0:  19%|████████▊                                     | 23/120 [00:01<00:04, 22.78it/s]
# Validation DataLoader 0:  20%|█████████▏                                    | 24/120 [00:01<00:04, 22.73it/s]
# Validation DataLoader 0:  21%|█████████▌                                    | 25/120 [00:01<00:04, 22.59it/s]
# Validation DataLoader 0:  22%|█████████▉                                    | 26/120 [00:01<00:04, 22.53it/s]
# Validation DataLoader 0:  22%|██████████▎                                   | 27/120 [00:01<00:04, 22.07it/s]
# Validation DataLoader 0:  23%|██████████▋                                   | 28/120 [00:01<00:04, 21.90it/s]
# Validation DataLoader 0:  24%|███████████                                   | 29/120 [00:01<00:04, 21.77it/s]
# Validation DataLoader 0:  25%|███████████▌                                  | 30/120 [00:01<00:04, 21.66it/s]
# Validation DataLoader 0:  26%|███████████▉                                  | 31/120 [00:01<00:04, 21.68it/s]
# Validation DataLoader 0:  27%|████████████▎                                 | 32/120 [00:01<00:04, 21.91it/s]
# Validation DataLoader 0:  28%|████████████▋                                 | 33/120 [00:01<00:03, 21.95it/s]
# Validation DataLoader 0:  28%|█████████████                                 | 34/120 [00:01<00:03, 22.04it/s]
# Validation DataLoader 0:  29%|█████████████▍                                | 35/120 [00:01<00:03, 22.00it/s]
# Validation DataLoader 0:  30%|█████████████▊                                | 36/120 [00:01<00:03, 21.93it/s]
# Validation DataLoader 0:  31%|██████████████▏                               | 37/120 [00:01<00:03, 21.88it/s]
# Validation DataLoader 0:  32%|██████████████▌                               | 38/120 [00:01<00:03, 21.87it/s]
# Validation DataLoader 0:  32%|██████████████▉                               | 39/120 [00:01<00:03, 21.92it/s]
# Validation DataLoader 0:  33%|███████████████▎                              | 40/120 [00:01<00:03, 21.80it/s]
# Validation DataLoader 0:  34%|███████████████▋                              | 41/120 [00:01<00:03, 21.73it/s]
# Validation DataLoader 0:  35%|████████████████                              | 42/120 [00:01<00:03, 21.59it/s]
# Validation DataLoader 0:  36%|████████████████▍                             | 43/120 [00:01<00:03, 21.51it/s]
# Validation DataLoader 0:  37%|████████████████▊                             | 44/120 [00:02<00:03, 21.53it/s]
/s]
# Validation DataLoader 0:  88%|███████████████████████████████████████▊     | 106/120 [00:04<00:00, 21.50it/s]
# Validation DataLoader 0:  89%|████████████████████████████████████████▏    | 107/120 [00:04<00:00, 21.53it/s]
# Validation DataLoader 0:  90%|████████████████████████████████████████▌    | 108/120 [00:05<00:00, 21.56it/s]
# Validation DataLoader 0:  91%|████████████████████████████████████████▉    | 109/120 [00:05<00:00, 21.58it/s]
# Validation DataLoader 0:  92%|█████████████████████████████████████████▎   | 110/120 [00:05<00:00, 21.57it/s]
# Validation DataLoader 0:  92%|█████████████████████████████████████████▋   | 111/120 [00:05<00:00, 21.62it/s]
# Validation DataLoader 0:  93%|██████████████████████████████████████████   | 112/120 [00:05<00:00, 21.64it/s]
# Validation DataLoader 0:  94%|██████████████████████████████████████████▍  | 113/120 [00:05<00:00, 21.71it/s]
# Validation DataLoader 0:  95%|██████████████████████████████████████████▊  | 114/120 [00:05<00:00, 21.78it/s]
# Validation DataLoader 0:  96%|███████████████████████████████████████████▏ | 115/120 [00:05<00:00, 21.83it/s]
# Validation DataLoader 0:  97%|███████████████████████████████████████████▌ | 116/120 [00:05<00:00, 21.86it/s]
# Validation DataLoader 0:  98%|███████████████████████████████████████████▉ | 117/120 [00:05<00:00, 21.90it/s]
# Validation DataLoader 0:  98%|████████████████████████████████████████████▎| 118/120 [00:05<00:00, 21.92it/s]
# Validation DataLoader 0:  99%|████████████████████████████████████████████▋| 119/120 [00:05<00:00, 21.94it/s]
# Epoch 4: 100%|████████████████████████████████████████████████████| 479/479 [00:57<00:00,  8.40it/s, v_num=0]
# Epoch 5: 100%|████████████████████████████████████████████████████| 479/479 [00:51<00:00,  9.32it/s, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                    | 0/120 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                       | 0/120 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|▍                                              | 1/120 [00:00<00:05, 19.98it/s]
# Validation DataLoader 0:   2%|▊                                              | 2/120 [00:00<00:05, 20.83it/s]
# Validation DataLoader 0:   2%|█▏                                             | 3/120 [00:00<00:06, 18.99it/s]
# Validation DataLoader 0:   3%|█▌                                             | 4/120 [00:00<00:06, 18.00it/s]
# Validation DataLoader 0:   4%|█▉                                             | 5/120 [00:00<00:06, 18.10it/s]
# Validation DataLoader 0:   5%|██▎                                            | 6/120 [00:00<00:06, 18.45it/s]
# Validation DataLoader 0:   6%|██▋                                            | 7/120 [00:00<00:06, 18.71it/s]
# Validation DataLoader 0:   7%|███▏                                           | 8/120 [00:00<00:06, 18.58it/s]
# Validation DataLoader 0:   8%|███▌                                           | 9/120 [00:00<00:05, 18.89it/s]
# Validation DataLoader 0:   8%|███▊                                          | 10/120 [00:00<00:05, 19.32it/s]
# Validation DataLoader 0:   9%|████▏                                         | 11/120 [00:00<00:05, 19.91it/s]
# Validation DataLoader 0:  10%|████▌                                         | 12/120 [00:00<00:05, 20.39it/s]
# Validation DataLoader 0:  11%|████▉                                         | 13/120 [00:00<00:05, 20.68it/s]
# Validation DataLoader 0:  12%|█████▎                                        | 14/120 [00:00<00:05, 20.73it/s]
# Validation DataLoader 0:  12%|█████▊                                        | 15/120 [00:00<00:05, 20.82it/s]
# Validation DataLoader 0:  13%|██████▏                                       | 16/120 [00:00<00:04, 20.93it/s]
# Validation DataLoader 0:  14%|██████▌                                       | 17/120 [00:00<00:04, 21.08it/s]
# Validation DataLoader 0:  15%|██████▉                                       | 18/120 [00:00<00:04, 21.34it/s]
# Validation DataLoader 0:  16%|███████▎                                      | 19/120 [00:00<00:04, 21.40it/s]
# Validation DataLoader 0:  17%|███████▋                                      | 20/120 [00:00<00:04, 21.65it/s]
# Validation DataLoader 0:  18%|████████                                      | 21/120 [00:00<00:04, 22.00it/s]
# Validation DataLoader 0:  18%|████████▍                                     | 22/120 [00:00<00:04, 22.32it/s]
# Validation DataLoader 0:  19%|████████▊                                     | 23/120 [00:01<00:04, 22.53it/s]
# Validation DataLoader 0:  20%|█████████▏                                    | 24/120 [00:01<00:04, 22.47it/s]
# Validation DataLoader 0:  21%|█████████▌                                    | 25/120 [00:01<00:04, 22.32it/s]
# Validation DataLoader 0:  22%|█████████▉                                    | 26/120 [00:01<00:04, 22.24it/s]
# Validation DataLoader 0:  22%|██████████▎                                   | 27/120 [00:01<00:04, 22.14it/s]
# Validation DataLoader 0:  23%|██████████▋                                   | 28/120 [00:01<00:04, 22.08it/s]
# Validation DataLoader 0:  24%|███████████                                   | 29/120 [00:01<00:04, 22.00it/s]
# Validation DataLoader 0:  25%|███████████▌                                  | 30/120 [00:01<00:04, 21.91it/s]
# Validation DataLoader 0:  26%|███████████▉                                  | 31/120 [00:01<00:04, 21.84it/s]
# Validation DataLoader 0:  27%|████████████▎                                 | 32/120 [00:01<00:04, 21.90it/s]
# Validation DataLoader 0:  28%|████████████▋                                 | 33/120 [00:01<00:03, 22.01it/s]
# Validation DataLoader 0:  28%|█████████████                                 | 34/120 [00:01<00:03, 21.98it/s]
# Validation DataLoader 0:  29%|█████████████▍                                | 35/120 [00:01<00:03, 22.02it/s]
# Validation DataLoader 0:  30%|█████████████▊                                | 36/120 [00:01<00:03, 22.00it/s]
# Validation DataLoader 0:  31%|██████████████▏                               | 37/120 [00:01<00:03, 21.89it/s]
# Validation DataLoader 0:  32%|██████████████▌                               | 38/120 [00:01<00:03, 21.75it/s]
# Validation DataLoader 0:  32%|██████████████▉                               | 39/120 [00:01<00:03, 21.53it/s]
# Validation DataLoader 0:  33%|███████████████▎                              | 40/120 [00:01<00:03, 21.27it/s]
# Validation DataLoader 0:  34%|███████████████▋                              | 41/120 [00:01<00:03, 21.13it/s]
# Validation DataLoader 0:  35%|████████████████                              | 42/120 [00:01<00:03, 21.02it/s]
# Validation DataLoader 0:  36%|████████████████▍                             | 43/120 [00:02<00:03, 20.88it/s]
# Validation DataLoader 0:  37%|████████████████▊                             | 44/120 [00:02<00:03, 20.85it/s]
# Validation DataLoader 0:  38%|█████████████████▎                            | 45/120 [00:02<00:03, 20.82it/s]
# Validation DataLoader 0:  38%|█████████████████▋                            | 46/120 [00:02<00:03, 20.83it/s]
# Validation DataLoader 0:  39%|██████████████████                            | 47/120 [00:02<00:03, 20.76it/s]
# Validation DataLoader 0:  40%|██████████████████▍                           | 48/120 [00:02<00:03, 20.79it/s]
# Validation DataLoader 0:  41%|██████████████████▊                           | 49/120 [00:02<00:03, 20.84it/s]
/s]
# Validation DataLoader 0:  95%|██████████████████████████████████████████▊  | 114/120 [00:05<00:00, 20.22it/s]
# Validation DataLoader 0:  96%|███████████████████████████████████████████▏ | 115/120 [00:05<00:00, 20.24it/s]
# Validation DataLoader 0:  97%|███████████████████████████████████████████▌ | 116/120 [00:05<00:00, 20.25it/s]
# Validation DataLoader 0:  98%|███████████████████████████████████████████▉ | 117/120 [00:05<00:00, 20.26it/s]
# Validation DataLoader 0:  98%|████████████████████████████████████████████▎| 118/120 [00:05<00:00, 20.30it/s]
# Validation DataLoader 0:  99%|████████████████████████████████████████████▋| 119/120 [00:05<00:00, 20.31it/s]
# Epoch 5: 100%|████████████████████████████████████████████████████| 479/479 [01:07<00:00,  7.14it/s, v_num=0]
# Epoch 6: 100%|████████████████████████████████████████████████████| 479/479 [00:50<00:00,  9.47it/s, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                    | 0/120 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                       | 0/120 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|▍                                              | 1/120 [00:00<00:09, 11.90it/s]
# Validation DataLoader 0:   2%|▊                                              | 2/120 [00:00<00:11,  9.85it/s]
# Validation DataLoader 0:   2%|█▏                                             | 3/120 [00:00<00:09, 11.72it/s]
# Validation DataLoader 0:   3%|█▌                                             | 4/120 [00:00<00:08, 13.21it/s]
# Validation DataLoader 0:   4%|█▉                                             | 5/120 [00:00<00:07, 14.41it/s]
# Validation DataLoader 0:   5%|██▎                                            | 6/120 [00:00<00:07, 15.14it/s]
# Validation DataLoader 0:   6%|██▋                                            | 7/120 [00:00<00:07, 16.04it/s]
# Validation DataLoader 0:   7%|███▏                                           | 8/120 [00:00<00:06, 16.75it/s]
# Validation DataLoader 0:   8%|███▌                                           | 9/120 [00:00<00:06, 17.11it/s]
# Validation DataLoader 0:   8%|███▊                                          | 10/120 [00:00<00:06, 17.28it/s]
# Validation DataLoader 0:   9%|████▏                                         | 11/120 [00:00<00:06, 17.19it/s]
# Validation DataLoader 0:  10%|████▌                                         | 12/120 [00:00<00:06, 17.28it/s]
# Validation DataLoader 0:  11%|████▉                                         | 13/120 [00:00<00:06, 17.14it/s]
# Validation DataLoader 0:  12%|█████▎                                        | 14/120 [00:00<00:06, 17.01it/s]
# Validation DataLoader 0:  12%|█████▊                                        | 15/120 [00:00<00:06, 17.21it/s]
# Validation DataLoader 0:  13%|██████▏                                       | 16/120 [00:00<00:06, 17.25it/s]
# Validation DataLoader 0:  14%|██████▌                                       | 17/120 [00:01<00:06, 16.98it/s]
# Validation DataLoader 0:  15%|██████▉                                       | 18/120 [00:01<00:06, 16.87it/s]
# Validation DataLoader 0:  16%|███████▎                                      | 19/120 [00:01<00:06, 16.62it/s]
# Validation DataLoader 0:  17%|███████▋                                      | 20/120 [00:01<00:06, 16.45it/s]
# Validation DataLoader 0:  18%|████████                                      | 21/120 [00:01<00:06, 16.25it/s]
# Validation DataLoader 0:  45%|████████████████████▋                         | 54/120 [00:03<00:04, 15.54it/s]
# Validation DataLoader 0:  46%|█████████████████████                         | 55/120 [00:03<00:04, 15.58it/s]
# Validation DataLoader 0:  47%|█████████████████████▍                        | 56/120 [00:03<00:04, 15.63it/s]
# Validation DataLoader 0:  48%|█████████████████████▊                        | 57/120 [00:03<00:04, 15.62it/s]
# Validation DataLoader 0:  48%|██████████████████████▏                       | 58/120 [00:03<00:03, 15.65it/s]
# Validation DataLoader 0:  49%|██████████████████████▌                       | 59/120 [00:03<00:03, 15.62it/s]
# Validation DataLoader 0:  50%|███████████████████████                       | 60/120 [00:03<00:03, 15.55it/s]
# Validation DataLoader 0:  51%|███████████████████████▍                      | 61/120 [00:03<00:03, 15.44it/s]
# Validation DataLoader 0:  52%|███████████████████████▊                      | 62/120 [00:04<00:03, 15.41it/s]
# Validation DataLoader 0:  52%|████████████████████████▏                     | 63/120 [00:04<00:03, 15.35it/s]
# Validation DataLoader 0:  53%|████████████████████████▌                     | 64/120 [00:04<00:03, 15.31it/s]
# Validation DataLoader 0:  54%|████████████████████████▉                     | 65/120 [00:04<00:03, 15.30it/s]
# Validation DataLoader 0:  55%|█████████████████████████▎                    | 66/120 [00:04<00:03, 15.28it/s]
# Validation DataLoader 0:  56%|█████████████████████████▋                    | 67/120 [00:04<00:03, 15.25it/s]
# Validation DataLoader 0:  57%|██████████████████████████                    | 68/120 [00:04<00:03, 15.23it/s]
# Validation DataLoader 0:  57%|██████████████████████████▍                   | 69/120 [00:04<00:03, 15.17it/s]
# Validation DataLoader 0:  58%|██████████████████████████▊                   | 70/120 [00:04<00:03, 14.87it/s]
# Validation DataLoader 0:  59%|███████████████████████████▏                  | 71/120 [00:04<00:03, 14.82it/s]
# Validation DataLoader 0:  60%|███████████████████████████▌                  | 72/120 [00:04<00:03, 14.82it/s]
# Validation DataLoader 0:  61%|███████████████████████████▉                  | 73/120 [00:04<00:03, 14.81it/s]
# Validation DataLoader 0:  62%|████████████████████████████▎                 | 74/120 [00:05<00:03, 14.79it/s]
# Validation DataLoader 0:  62%|████████████████████████████▊                 | 75/120 [00:05<00:03, 14.77it/s]
# Validation DataLoader 0:  63%|█████████████████████████████▏                | 76/120 [00:05<00:02, 14.80it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: 120it [00:12,  9.56it/s]
# ViT results {'test': 0.359327107667923}

# %%
test_result = trainer.test(model, test_dl, verbose=False)
result = {"test": test_result[0]["test_acc"]}
print("ViT results", result)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|████████████████████████████████████████████████| 120/120 [00:05<00:00, 23.55it/s]
# ViT results {'test': 0.359327107667923}

# %%
# Opens tensorboard in notebook. Adjust the path to your CHECKPOINT_PATH!
# %load_ext tensorboard
# %tensorboard --logdir="I:\model_ckpts\ViT_LC_LST_02\tensorboard" --port=8893
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 8893 (pid 12564), started 0:07:27 ago. (Use '!kill 12564' to kill it.)
#       <iframe id="tensorboard-frame-1c80317fa3b1799d" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-1c80317fa3b1799d");
#           const url = new URL("/", window.location);
#           const port = 8893;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ---
