# %%
import pandas as pd
import os
import random
ds_assigned_roll

pd.options.mode.chained_assignment = None

# %%
st_roll_fn=r'C:\Users\richie\omen_richiebao\omen_XAUAT\course_2023_autumn\python 建大点名册_20230910.xlsx'
ds_root=r'C:\Users\richie\omen_richiebao\omen_XAUAT\datasets'
ds_assigned_roll=r'C:\Users\richie\omen_richiebao\omen_XAUAT\course_2023_autumn\ds_assigned_roll_%s.csv'%(datetime.datetime.now().strftime('%y%m%d_%H%M'))

ds_name=os.listdir(ds_root)
random.shuffle(ds_name)

st_roll=pd.read_excel(st_roll_fn,skiprows=5,dtype='str')[:-1]
st_id_name=st_roll[['Unnamed: 1','Unnamed: 2']]

st_id_name['ds']=ds_name[:17]
st_id_name.to_csv(ds_assigned_roll)
st_id_name
# Out:
#     Unnamed: 1 Unnamed: 2                                                 ds
# 0   2112020120         李曦  Budget_-_2015_Budget_Ordinance_-_Positions_and...
# 1   2115010114         张婧  Public_Passenger_Vehicle_Chauffeur_Survey_-_20...
# 2   2201010001        赵承志  Libraries_-_2021_Computer_Sessions_by_Location...
# 3   2201010006        康铭俊                                    Green_Roofs.csv
# 4   2201010013        杜思懿  Employee_Overtime_and_Supplemental_Earnings_20...
# 5   2201010018        周容西  Chicago_Public_Schools_-_School_Profile_Inform...
# 6   2201010062        高宇欣  COVID-19_Daily_Cases__Deaths__and_Hospitalizat...
# 7   2201010095         杨涵                   Average_Daily_Traffic_Counts.csv
# 8   2201010117        晏开扬  Public_Health_Statistics_-_Births_to_mothers_a...
# 9   2201010121        李佳奇  Budget_-_2011_Budget_Ordinance_-_Positions_and...
# 10  2201010125        郑宗兴  Current_Employee_Names__Salaries__and_Position...
# ...
